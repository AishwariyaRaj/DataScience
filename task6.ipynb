# %% [markdown]
# <a href="https://colab.research.google.com/github/AishwariyaRaj/DataScience/blob/main/task6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MOUNTING G-DRIVE IN GOOGLE COLAB

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# IMPORTING LIBRARY FUNCTION

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# READING THE CSV DATA
#
# DISPLAYING THE DATA BY HEAD() FUNCTION

# %%
data=pd.read_csv("/content/gdrive/MyDrive/StudentsPerformance.csv")
data.head(6)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# 5                    none          71             83             78

# %% [markdown]
# CREATING IN COLUMNS

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
# GENERATING GRAPH FOR THIS DATA

# %%
data.plot(kind='line',x='gender',y='math score',alpha=0.5,color='red')
plt.xlabel('gender')
plt.ylabel('math score')
plt.title('student performance')
# Out:
# Text(0.5, 1.0, 'student performance')

# %% [markdown]
# GENERATING GRAPH FOR ALL DATA

# %%
data1 = data.loc[:,["writing score","reading score","math score"]]
data1.plot()
# Out:
# <Axes: >

# %%
data1.plot(kind = "scatter",x="writing score",y = "math score")
plt.show()

# %%
data1.plot(kind = "hist",y = "writing score",bins = 50,range= (0,250))
# Out:
# <Axes: ylabel='Frequency'>

# %%
a=data['writing score']>99
data[a]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 377  female        group D             master's degree  free/reduced
# 403  female        group D                 high school      standard
# 458  female        group E           bachelor's degree      standard
# 566  female        group E           bachelor's degree  free/reduced
# 685  female        group E             master's degree      standard
# 903  female        group D           bachelor's degree  free/reduced
# 916    male        group E           bachelor's degree      standard
# 957  female        group D             master's degree      standard
# 962  female        group E          associate's degree      standard
# ...

# %% [markdown]
# USING FOR LOOP

# %%
for key,value in data[['gender']][1:5].iterrows():
  print(value)
# Out:
# gender    female
# Name: 1, dtype: object
# gender    female
# Name: 2, dtype: object
# gender    male
# Name: 3, dtype: object
# gender    male
# Name: 4, dtype: object

# %% [markdown]
# SHAPE OF THE DATA

# %%
data.shape
# Out:
# (1000, 8)

# %% [markdown]
# DESCRIBING THE DATA

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# DATAS TYPES

# %%
data.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
data['reading score'] = data['reading score'].astype('category')
data['writing score'] = data['writing score'].astype('float')
print(data['reading score'])
# Out:
# 0      72
# 1      90
# 2      95
# 3      57
# 4      78
#        ..
# 995    99
# 996    55
# 997    71
# 998    78
# 999    86
# Name: reading score, Length: 1000, dtype: category
# Categories (72, int64): [17, 23, 24, 26, ..., 96, 97, 99, 100]

# %%
print(data['writing score'])
# Out:
# 0      74.0
# 1      88.0
# 2      93.0
# 3      44.0
# 4      75.0
#        ...
# 995    95.0
# 996    55.0
# 997    65.0
# 998    77.0
# 999    86.0
# Name: writing score, Length: 1000, dtype: float64

# %%
data.boxplot(column='math score',by='reading score')
# Out:
# <Axes: title={'center': 'math score'}, xlabel='reading score'>

# %% [markdown]
# MODIFYING THE DATA BY MELT()FUNCTION

# %%
melted=pd.melt(frame=data,id_vars='gender',value_vars=['reading score','writing score'])
melted
# Out:
#       gender       variable  value
# 0     female  reading score     72
# 1     female  reading score     90
# 2     female  reading score     95
# 3       male  reading score     57
# 4       male  reading score     78
# ...      ...            ...    ...
# 1995  female  writing score     95
# 1996    male  writing score     55
# 1997  female  writing score     65
# 1998  female  writing score     77
# 1999  female  writing score     86
#
# [2000 rows x 3 columns]

# %% [markdown]
# COUNT THE DATA BY DROUPNA () IN PANDAS

# %%
data['lunch'].value_counts(dropna=False)
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %% [markdown]
# SUBPLOTING THE GRAPH FOR THE INPUT DATA

# %%
data.plot(subplots=True)
plt.show()

# %% [markdown]
# INFO()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# CORR() FOR INPUT DATA

# %%
data.corr()
# Out:
# <ipython-input-9-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()
# Out:
# <ipython-input-10-36a057762ca3>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %% [markdown]
# CONVERTING THE DATA INTO SERIES AND DATAFRAME

# %%
series = data['math score']
print(type(series))
data_frame = data[['math score']]
print(type(data_frame))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
data[np.logical_and(data['reading score']>200, data['writing score']>100 )]
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score]
# Index: []

# %% [markdown]
# IMPORTING BUILTINS

# %%
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
# ...

# %% [markdown]
# BY USING TAIL()

# %%
data.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %% [markdown]
# CONCATENATING TWO DATA

# %%
# Firstly lets create 2 data frame
data1 = data.head()
data2= data.tail()
conc_data_row = pd.concat([data1,data2],axis =0,ignore_index =True)
conc_data_row
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group E             master's degree      standard
# 6    male        group C                 high school  free/reduced
# 7  female        group C                 high school  free/reduced
# 8  female        group D                some college      standard
# 9  female        group D                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
data1 = data['math score'].head()
data2= data['reading score'].head()
conc_data_col = pd.concat([data1,data2],axis =1)
conc_data_col
# Out:
#    math score  reading score
# 0          72             72
# 1          69             90
# 2          90             95
# 3          47             57
# 4          76             78

# %%
data= data.set_index("writing score")
data.head()
# Out:
#                gender race/ethnicity parental level of education  \
# writing score
# 74.0           female        group B           bachelor's degree
# 88.0           female        group C                some college
# 93.0           female        group B             master's degree
# 44.0             male        group A          associate's degree
# 75.0             male        group C                some college
#
#                       lunch test preparation course  math score reading score
# writing score
# 74.0               standard                    none          72            72
# 88.0               standard               completed          69            90
# 93.0               standard                    none          90            95
# 44.0           free/reduced                    none          47            57
# 75.0               standard                    none          76            78
